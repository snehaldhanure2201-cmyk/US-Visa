# %% [markdown]
# #### 2.1 Import Data and Required Packages

# %% [markdown]
# Importing Pandas,Numpy,Seaborn,Matplotlib and Warnings Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# Import the CSV data as a Pandas DataFrame

# %%
df = pd.read_csv(r"Visadataset.csv")

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.shape
# Out:
# (25480, 12)

# %%
df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
df.info
# Out:
# <bound method DataFrame.info of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# #### 3.Exploring Data

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 3 numerical features : ['no_of_employees', 'yr_of_estab', 'prevailing_wage']
#
# We have 9 categorical features : ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']

# %%
friend_list = ['A','B','C','D']
for f in friend_list:
  print("Hello"+f)
# Out:
# HelloA
# HelloB
# HelloC
# HelloD

# %%
friend_list = ['A','B','C','D']
f for f in friend_list:
  print("Hello"+f)
# Out:
#   Cell In[35], line 2
#     f for f in friend_list:
#       ^
# SyntaxError: invalid syntax

# %%
friend_list = ['A','B','C','D']
g for f in friend_list:
  print("Hello"+f)
# Out:
#   Cell In[13], line 2
#     g for f in friend_list:
#       ^
# SyntaxError: invalid syntax

# %%
friend_list = ['A','B','C','D']
new_list = [f for f in friend_list]
print (new_list)
# Out:
# ['A', 'B', 'C', 'D']

# %%
friend_list = ['A','B','C','D']
new_list = [g for f in friend_list]
print (new_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 friend_list = ['A','B','C','D']
# ----> 2 new_list = [g for f in friend_list]
#       3 print (new_list)
#
# Cell In[18], line 2, in <listcomp>(.0)
#       1 friend_list = ['A','B','C','D']
# ----> 2 new_list = [g for f in friend_list]
#       3 print (new_list)
#
# NameError: name 'g' is not defined

# %%
friend_list = ['A','B','C','D']
new_list = [g for g in friend_list]
print (new_list)
# Out:
# ['A', 'B', 'C', 'D']

# %%
# f for f or g for g, in variable_name sirf [] me chalta hai (nyi list bnane ke liye)
# for f in or for g in variable_name bina brackets ke chalta hai (print ya calculation krne ke liye)
#jb hm shuru me f (ya koi value) likhte hai to python ise ek list bnane ka shortcut samzta hai,
#  esliye [] jruri hota hai ,jaise ki upr ka code

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df[feature].dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df[feature].dtype
#
# NameError: name 'feature' is not defined

# %%
'''Gemini said 

1. The Variables

numeric_features: This is a list containing the names of columns that hold quantitative data
(e.g., Age, Price, Salary).

categorical_features: This is a list containing the names of columns that hold qualitative data or labels 
(e.g., Gender, Color, Country).

2. The Logic


The code uses the .format() method to plug specific values into a string of text:

len(...): This calculates the count (length) of how many features are in that list.

The {} placeholders: These act as "empty seats." The first {} gets filled by the count, 
and the second {} gets filled by the actual list of names.

\n: This is a "newline" character that adds a blank line between the two print statements for better readability.

3. What the Output Looks Like

If you were analyzing a dataset of used cars, the output might look like this:

We have 2 numerical features : ['Price', 'Mileage']

We have 2 categorical features : ['Brand', 'Fuel_Type']'''

# %% [markdown]
# ### Proportion of count Data in categorical columns

# %%
for col in categorical_features:
    print (df[col].value_counts(normalize=True) * 100)
    print('-------------------------------')
# Out:
# case_id
# EZYV01       0.003925
# EZYV16995    0.003925
# EZYV16993    0.003925
# EZYV16992    0.003925
# EZYV16991    0.003925
#                ...
# EZYV8492     0.003925
# EZYV8491     0.003925
# EZYV8490     0.003925
# EZYV8489     0.003925
# EZYV25480    0.003925
# Name: proportion, Length: 25480, dtype: float64
# -------------------------------
# continent
# Asia             66.173469
# Europe           14.646782
# North America    12.919937
# South America     3.343799
# Africa            2.162480
# Oceania           0.753532
# Name: proportion, dtype: float64
# -------------------------------
# education_of_employee
# Bachelor's     40.164835
# Master's       37.810047
# High School    13.422292
# Doctorate       8.602826
# Name: proportion, dtype: float64
# -------------------------------
# has_job_experience
# Y    58.092622
# N    41.907378
# Name: proportion, dtype: float64
# -------------------------------
# requires_job_training
# N    88.402669
# Y    11.597331
# ...

# %%
employees_number = df['no_of_employees'].tolist()
print(employees_number)
# Out:
# [14513, 2412, 44444, 98, 1082, 2339, 4985, 3035, 4810, 2251, 2465, 4069, 123876, 1652, 15756, 4897, 76638, 2747, 4743, 843, 880, 1706, 2878, 1517, 241, 1100, 756, 2889, 18, 758, 1408, 995, 2415, 2395, 1809, 5512, 2520, 44, 2206, 3729, 3723, 1209, 19770, 2582, 5407, 2092, 2623, 226, 2405, 2171, 746, 3129, 1647, 2438, 11733, 2368, 779, 2825, 3510, 2624, 5340, 2311, 5110, 1316, 100, 2021, 80, 2070, 2654, 292, 1320, 1722, 3339, 452, 3705, 85, 2423, 1274, 1549, 1062, 32619, 4036, 39, 2359, 1023, 2480, 1255, 4455, 2543, 1359, 2324, 4103, 3667, 488, 2724, 1392, 2573, 3524, 1847, 107535, 2227, 334, 224, 367, 306, 2317, 890, 2002, 2903, 2504, 951, 1327, 2421, 1019, 1048, 3323, 509, 2225, 1641, 1144, 2334, 1415, 2754, 1099, 960, 2750, 2753, 23287, 2140, 4499, 2554, 1333, 928, 4289, 113282, 1948, 1933, 2847, 1195, 54, 4390, 73909, 545, 2831, 1634, 1810, 3290, 472, 4273, 2326, 50351, 2261, 255, 373, 22, 3102, 5147, 284, 1926, 2510, 1200, 337, 2880, 816, 2640, 4190, 459, 3351, 3639, 373, 201, 546
# ...

# %%
df['no_of_employees'].max()
# Out:
# 602069

# %%
df['no_of_employees'].min()
# Out:
# -26
